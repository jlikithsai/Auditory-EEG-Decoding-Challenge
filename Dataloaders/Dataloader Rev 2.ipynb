# %%
import itertools
import os
import numpy as np
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import glob
import json
import logging
import sys
import torch.nn as nn
import torch.optim as optim
import random
def batch_equalizer_fn(args):
    eeg = args[0]
#     print("eegshape=",eeg.shape)
    num_stimuli = len(args) - 1
    # repeat eeg num_stimuli times
    new_eeg = torch.cat([eeg] * num_stimuli, dim=0)
    all_features = [new_eeg]
#     print("all_features=",all_features[0].shape)

    # create args
    args_to_zip = [args[i::num_stimuli] for i in range(1, num_stimuli + 1)]
#     print("args_to_zip=",args_to_zip[0].shape,args_to_zip[1].shape)

    for stimuli_features in zip(*args_to_zip):
#         print("stimuli_features=",stimuli_features[0].shape,stimuli_features[1].shape)
        for i in range(num_stimuli):
            shift = i
            shifted_tuple = tuple(stimuli_features[(j - shift) % len(stimuli_features)] for j in range(len(stimuli_features)))
#             print(len(shifted_tuple))
            stimulus_rolled = torch.stack(shifted_tuple)
#             print("stimulus_rolled=", stimulus_rolled.shape)
            # reshape stimulus_rolled to merge the first two dimensions
            stimulus_rolled = stimulus_rolled.view(-1, stimulus_rolled.size(2), stimulus_rolled.size(3))
#             print("stimulus_rolled1=", stimulus_rolled.shape)

            all_features.append(stimulus_rolled)
#     print("all_features1=",all_features)
    
    labels_list = [torch.tensor([[1 if ii == i else 0 for ii in range(num_stimuli)]]) for i in range(num_stimuli)]
    labels = torch.cat([label.repeat(eeg.size(0), 1) for label in labels_list], dim=0)
#     print("labels=",labels)
#     print("tuple(all_features)=", tuple(all_features))

    return tuple(all_features), labels

def shuffle_fn(args, number_mismatch):
    # repeat the last argument number_mismatch times
    args = list(args)
    for _ in range(number_mismatch):
        args.append(args[-1][torch.randperm(args[-1].size(0))])
    return tuple(args)

# Function to create frames from a tensor
def frame_tensor(tensor, window_length, hop_length):
    num_frames = (tensor.size(0) - window_length) // hop_length + 1
    frames = torch.stack(
        [tensor[i * hop_length : i * hop_length + window_length] for i in range(num_frames)]
    )
    return frames

def process_eeg(original_tensors_list):
    reshaped_tensors = [tensor[i].view(320, 64) for tensor in original_tensors_list for i in range(tensor.size(0))]

    lists_of_tensors = [reshaped_tensors[i:i+8] for i in range(0, len(reshaped_tensors), 8)]
    lists_of_tensors = lists_of_tensors[:len(reshaped_tensors)//8]

    # Shuffle the lists
    random.shuffle(lists_of_tensors)

    final_tensors = []
    for chunk_of_lists in zip(*(iter(lists_of_tensors),) * 8):
        concatenated_tensors = torch.cat([torch.unsqueeze(tensor, 0) for sublist in chunk_of_lists for tensor in sublist], dim=0).view(64, 320, 64)
        final_tensors.append(concatenated_tensors)

    return final_tensors
def process_stimuli(original_tensors_list):
    reshaped_tensors = [tensor[i].view(320, 10) for tensor in original_tensors_list for i in range(tensor.size(0))]

    lists_of_tensors = [reshaped_tensors[i:i+8] for i in range(0, len(reshaped_tensors), 8)]
    lists_of_tensors = lists_of_tensors[:len(reshaped_tensors)//8]

    # Shuffle the lists
    random.shuffle(lists_of_tensors)

    final_tensors = []
    for chunk_of_lists in zip(*(iter(lists_of_tensors),) * 8):
        concatenated_tensors = torch.cat([torch.unsqueeze(tensor, 0) for sublist in chunk_of_lists for tensor in sublist], dim=0).view(64, 320, 10)
        final_tensors.append(concatenated_tensors)

    return final_tensors
class PyTorchDataGenerator(Dataset):
    def __init__(self, files, window_length):
        self.window_length = window_length
        self.files = self.group_recordings(files)

    def group_recordings(self, files):
        new_files = []
        grouped = itertools.groupby(
            sorted(files), lambda x: "_-_".join(os.path.basename(x).split("_-_")[:3])
        )
        for recording_name, feature_paths in grouped:
            new_files += [sorted(feature_paths, key=lambda x: "0" if x == "eeg" else x)]
#         print("new_files=", new_files[0:2])
        return new_files
    

    def __len__(self):
        return len(self.files)

    def __getitem__(self, recording_index):
        data = []
        file_names = []
        for feature in self.files[recording_index]:
            f = np.load(feature).astype(np.float32)
#             print("f_before=", f.shape)
            if f.ndim == 1:
                f = f[:, None]
#                 print("f_after=", f.shape)
            data += [f]
            file_names += [os.path.basename(feature)]
#         print("data_before=", data)
        data = self.prepare_data(data)
        
#         print("data_after=", data)
#         print("tuple(torch.tensor(x) for x in data)=",tuple(torch.tensor(x) for x in data))
        return tuple(torch.tensor(x) for x in data), file_names

    def __call__(self):
        for idx in range(self.__len__()):
            yield self.__getitem__(idx)

            if idx == self.__len__() - 1:
                self.on_epoch_end()

    def on_epoch_end(self):
        np.random.shuffle(self.files)

    def prepare_data(self, data):
        # make sure data has dimensionality of (n_samples, n_features)
        return data



window_length_s = 5
fs = 64

window_length = window_length_s * fs  # 5 seconds
# Hop length between two consecutive decision windows
hop_length = 64

epochs = 100
patience = 5
batch_size = 64 #fixed in the code
only_evaluate = True
number_mismatch = 4 # or 4



training_log_filename = "training_log_{}_{}.csv".format(number_mismatch, window_length_s)
data_folder = "split_data/split_data"

# stimulus feature which will be used for training the model. Can be either 'envelope' ( dimension 1) or 'mel' (dimension 28)
stimulus_features = ["mel"]
stimulus_dimension = 10

# uncomment if you want to train with the mel spectrogram stimulus representation
# stimulus_features = ["mel"]
# stimulus_dimension = 10

features = ["eeg"] + stimulus_features
# print("features=", features)
train_files = [x for x in glob.glob(os.path.join(data_folder, "train_-_*")) if os.path.basename(x).split("_-_")[-1].split(".")[0] in features]
# Create list of numpy array files
train_generator = PyTorchDataGenerator(train_files, window_length)

# %%
i=0
for batch in train_generator:
    print(batch[0][0].shape,batch[0][1].shape, batch[1])
# Out:
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-001_-_audiobook_1_-_eeg.npy', 'train_-_sub-001_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-001_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-001_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-001_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-001_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-001_-_audiobook_3_-_eeg.npy', 'train_-_sub-001_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-001_-_audiobook_4_-_eeg.npy', 'train_-_sub-001_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-001_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-001_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-001_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-001_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-001_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-001_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-001_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-001_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-001_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-001_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-002_-_audiobook_1_-_eeg.npy', 'train_-_sub-002_-_audiobook_1_-_mel.npy']
# torch.Size([15376, 64]) torch.Size([15376, 10]) ['train_-_sub-002_-_audiobook_1_artefact_-_eeg.npy', 'train_-_sub-002_-_audiobook_1_artefact_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-002_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-002_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-002_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-002_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-002_-_audiobook_3_-_eeg.npy', 'train_-_sub-002_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-002_-_audiobook_4_-_eeg.npy', 'train_-_sub-002_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-002_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-002_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-002_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-002_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-002_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-002_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-002_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-002_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-002_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-002_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-003_-_audiobook_1_-_eeg.npy', 'train_-_sub-003_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-003_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-003_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-003_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-003_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-003_-_audiobook_3_-_eeg.npy', 'train_-_sub-003_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-003_-_audiobook_4_-_eeg.npy', 'train_-_sub-003_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-003_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-003_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-003_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-003_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-003_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-003_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-003_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-003_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-003_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-003_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-004_-_audiobook_1_-_eeg.npy', 'train_-_sub-004_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-004_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-004_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-004_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-004_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-004_-_audiobook_3_-_eeg.npy', 'train_-_sub-004_-_audiobook_3_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-005_-_audiobook_1_-_eeg.npy', 'train_-_sub-005_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-005_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-005_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-005_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-005_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-005_-_audiobook_3_-_eeg.npy', 'train_-_sub-005_-_audiobook_3_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-005_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-005_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-005_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-005_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-005_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-005_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-005_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-005_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-005_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-005_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-006_-_audiobook_1_-_eeg.npy', 'train_-_sub-006_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-006_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-006_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-006_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-006_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-006_-_audiobook_3_-_eeg.npy', 'train_-_sub-006_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-006_-_audiobook_4_-_eeg.npy', 'train_-_sub-006_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-006_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-006_-_audiobook_5_1_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-006_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-006_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-006_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-006_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-006_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-006_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-007_-_audiobook_1_-_eeg.npy', 'train_-_sub-007_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-007_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-007_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-007_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-007_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-007_-_audiobook_3_-_eeg.npy', 'train_-_sub-007_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-007_-_audiobook_4_-_eeg.npy', 'train_-_sub-007_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-007_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-007_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-007_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-007_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-007_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-007_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-007_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-007_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-007_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-007_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-008_-_audiobook_1_-_eeg.npy', 'train_-_sub-008_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-008_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-008_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-008_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-008_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-008_-_audiobook_3_-_eeg.npy', 'train_-_sub-008_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-008_-_audiobook_4_-_eeg.npy', 'train_-_sub-008_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-008_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-008_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-008_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-008_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-008_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-008_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-008_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-008_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-008_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-008_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-009_-_audiobook_1_-_eeg.npy', 'train_-_sub-009_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-009_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-009_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-009_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-009_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-009_-_audiobook_3_-_eeg.npy', 'train_-_sub-009_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-009_-_audiobook_4_-_eeg.npy', 'train_-_sub-009_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-009_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-009_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-009_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-009_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-009_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-009_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-009_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-009_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-009_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-009_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-010_-_audiobook_1_-_eeg.npy', 'train_-_sub-010_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-010_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-010_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-010_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-010_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-010_-_audiobook_3_-_eeg.npy', 'train_-_sub-010_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-010_-_audiobook_4_-_eeg.npy', 'train_-_sub-010_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-010_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-010_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-010_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-010_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-010_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-010_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-010_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-010_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-010_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-010_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-011_-_audiobook_1_-_eeg.npy', 'train_-_sub-011_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-011_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-011_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-011_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-011_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-011_-_audiobook_3_-_eeg.npy', 'train_-_sub-011_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-011_-_audiobook_4_-_eeg.npy', 'train_-_sub-011_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-011_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-011_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-011_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-011_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-011_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-011_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-011_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-011_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-011_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-011_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-012_-_audiobook_1_-_eeg.npy', 'train_-_sub-012_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-012_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-012_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-012_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-012_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-012_-_audiobook_3_-_eeg.npy', 'train_-_sub-012_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-012_-_audiobook_4_-_eeg.npy', 'train_-_sub-012_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-012_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-012_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-012_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-012_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-012_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-012_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-012_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-012_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-012_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-012_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-013_-_audiobook_1_-_eeg.npy', 'train_-_sub-013_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-013_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-013_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-013_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-013_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-013_-_audiobook_3_-_eeg.npy', 'train_-_sub-013_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-013_-_audiobook_4_-_eeg.npy', 'train_-_sub-013_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-013_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-013_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-013_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-013_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-013_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-013_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-013_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-013_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-013_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-013_-_audiobook_6_2_-_mel.npy']
# torch.Size([23417, 64]) torch.Size([23417, 10]) ['train_-_sub-014_-_audiobook_1_1_-_eeg.npy', 'train_-_sub-014_-_audiobook_1_1_-_mel.npy']
# torch.Size([21434, 64]) torch.Size([21434, 10]) ['train_-_sub-014_-_audiobook_1_2_shifted_-_eeg.npy', 'train_-_sub-014_-_audiobook_1_2_shifted_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-014_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-014_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-014_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-014_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-014_-_audiobook_3_-_eeg.npy', 'train_-_sub-014_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-014_-_audiobook_4_-_eeg.npy', 'train_-_sub-014_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-014_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-014_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-014_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-014_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-014_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-014_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-014_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-014_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-014_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-014_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-015_-_audiobook_1_-_eeg.npy', 'train_-_sub-015_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-015_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-015_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-015_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-015_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-015_-_audiobook_3_-_eeg.npy', 'train_-_sub-015_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-015_-_audiobook_4_-_eeg.npy', 'train_-_sub-015_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-015_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-015_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-015_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-015_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-015_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-015_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-015_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-015_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-015_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-015_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-016_-_audiobook_1_-_eeg.npy', 'train_-_sub-016_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-016_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-016_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-016_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-016_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-016_-_audiobook_3_-_eeg.npy', 'train_-_sub-016_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-016_-_audiobook_4_-_eeg.npy', 'train_-_sub-016_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-016_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-016_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-016_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-016_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-016_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-016_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-016_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-016_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-016_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-016_-_audiobook_6_2_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-017_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-017_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-017_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-017_-_audiobook_2_2_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-017_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-017_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-017_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-017_-_audiobook_5_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-018_-_audiobook_1_-_eeg.npy', 'train_-_sub-018_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-018_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-018_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-018_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-018_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-018_-_audiobook_3_-_eeg.npy', 'train_-_sub-018_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-018_-_audiobook_4_-_eeg.npy', 'train_-_sub-018_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-018_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-018_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-018_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-018_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-018_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-018_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-018_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-018_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-018_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-018_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-019_-_audiobook_1_-_eeg.npy', 'train_-_sub-019_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-019_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-019_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-019_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-019_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-019_-_audiobook_3_-_eeg.npy', 'train_-_sub-019_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-019_-_audiobook_4_-_eeg.npy', 'train_-_sub-019_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-019_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-019_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-019_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-019_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-019_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-019_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-019_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-019_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-019_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-019_-_audiobook_6_2_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-020_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-020_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-020_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-020_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-020_-_audiobook_3_-_eeg.npy', 'train_-_sub-020_-_audiobook_3_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-020_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-020_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-020_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-020_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-020_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-020_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-020_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-020_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-020_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-020_-_audiobook_6_2_-_mel.npy']
# torch.Size([23417, 64]) torch.Size([23417, 10]) ['train_-_sub-021_-_audiobook_1_1_-_eeg.npy', 'train_-_sub-021_-_audiobook_1_1_-_mel.npy']
# torch.Size([21434, 64]) torch.Size([21434, 10]) ['train_-_sub-021_-_audiobook_1_2_shifted_-_eeg.npy', 'train_-_sub-021_-_audiobook_1_2_shifted_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-021_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-021_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-021_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-021_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-021_-_audiobook_3_-_eeg.npy', 'train_-_sub-021_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-021_-_audiobook_4_-_eeg.npy', 'train_-_sub-021_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-021_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-021_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-021_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-021_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-021_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-021_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-021_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-021_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-021_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-021_-_audiobook_6_2_-_mel.npy']
# torch.Size([23417, 64]) torch.Size([23417, 10]) ['train_-_sub-022_-_audiobook_1_1_-_eeg.npy', 'train_-_sub-022_-_audiobook_1_1_-_mel.npy']
# torch.Size([21434, 64]) torch.Size([21434, 10]) ['train_-_sub-022_-_audiobook_1_2_shifted_-_eeg.npy', 'train_-_sub-022_-_audiobook_1_2_shifted_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-022_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-022_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-022_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-022_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-022_-_audiobook_3_-_eeg.npy', 'train_-_sub-022_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-022_-_audiobook_4_-_eeg.npy', 'train_-_sub-022_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-022_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-022_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-022_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-022_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-022_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-022_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-022_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-022_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-022_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-022_-_audiobook_6_2_-_mel.npy']
# torch.Size([23417, 64]) torch.Size([23417, 10]) ['train_-_sub-023_-_audiobook_1_1_shifted_-_eeg.npy', 'train_-_sub-023_-_audiobook_1_1_shifted_-_mel.npy']
# torch.Size([21434, 64]) torch.Size([21434, 10]) ['train_-_sub-023_-_audiobook_1_2_-_eeg.npy', 'train_-_sub-023_-_audiobook_1_2_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-023_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-023_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-023_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-023_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-023_-_audiobook_3_-_eeg.npy', 'train_-_sub-023_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-023_-_audiobook_4_-_eeg.npy', 'train_-_sub-023_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-023_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-023_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-023_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-023_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-023_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-023_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-023_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-023_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-023_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-023_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-024_-_audiobook_1_-_eeg.npy', 'train_-_sub-024_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-024_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-024_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-024_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-024_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-024_-_audiobook_3_-_eeg.npy', 'train_-_sub-024_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-024_-_audiobook_4_-_eeg.npy', 'train_-_sub-024_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-024_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-024_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-024_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-024_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-024_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-024_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-024_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-024_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-024_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-024_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-025_-_audiobook_1_-_eeg.npy', 'train_-_sub-025_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-025_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-025_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-025_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-025_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-025_-_audiobook_3_-_eeg.npy', 'train_-_sub-025_-_audiobook_3_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-025_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-025_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-025_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-025_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-025_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-025_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-025_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-025_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-025_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-025_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-026_-_audiobook_1_-_eeg.npy', 'train_-_sub-026_-_audiobook_1_-_mel.npy']
# torch.Size([40492, 64]) torch.Size([40492, 10]) ['train_-_sub-026_-_audiobook_2_1_-_eeg.npy', 'train_-_sub-026_-_audiobook_2_1_-_mel.npy']
# torch.Size([38995, 64]) torch.Size([38995, 10]) ['train_-_sub-026_-_audiobook_2_2_-_eeg.npy', 'train_-_sub-026_-_audiobook_2_2_-_mel.npy']
# torch.Size([49276, 64]) torch.Size([49276, 10]) ['train_-_sub-026_-_audiobook_3_-_eeg.npy', 'train_-_sub-026_-_audiobook_3_-_mel.npy']
# torch.Size([41645, 64]) torch.Size([41645, 10]) ['train_-_sub-026_-_audiobook_4_-_eeg.npy', 'train_-_sub-026_-_audiobook_4_-_mel.npy']
# torch.Size([46391, 64]) torch.Size([46391, 10]) ['train_-_sub-026_-_audiobook_5_1_-_eeg.npy', 'train_-_sub-026_-_audiobook_5_1_-_mel.npy']
# torch.Size([46572, 64]) torch.Size([46572, 10]) ['train_-_sub-026_-_audiobook_5_2_-_eeg.npy', 'train_-_sub-026_-_audiobook_5_2_-_mel.npy']
# torch.Size([48789, 64]) torch.Size([48789, 10]) ['train_-_sub-026_-_audiobook_5_3_-_eeg.npy', 'train_-_sub-026_-_audiobook_5_3_-_mel.npy']
# torch.Size([42677, 64]) torch.Size([42677, 10]) ['train_-_sub-026_-_audiobook_6_1_-_eeg.npy', 'train_-_sub-026_-_audiobook_6_1_-_mel.npy']
# torch.Size([42668, 64]) torch.Size([42668, 10]) ['train_-_sub-026_-_audiobook_6_2_-_eeg.npy', 'train_-_sub-026_-_audiobook_6_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-027_-_audiobook_1_-_eeg.npy', 'train_-_sub-027_-_audiobook_1_-_mel.npy']
# torch.Size([12579, 64]) torch.Size([12579, 10]) ['train_-_sub-027_-_audiobook_7_1_-_eeg.npy', 'train_-_sub-027_-_audiobook_7_1_-_mel.npy']
# torch.Size([12381, 64]) torch.Size([12381, 10]) ['train_-_sub-027_-_audiobook_7_2_-_eeg.npy', 'train_-_sub-027_-_audiobook_7_2_-_mel.npy']
# torch.Size([12055, 64]) torch.Size([12055, 10]) ['train_-_sub-027_-_audiobook_7_3_-_eeg.npy', 'train_-_sub-027_-_audiobook_7_3_-_mel.npy']
# torch.Size([16715, 64]) torch.Size([16715, 10]) ['train_-_sub-027_-_audiobook_7_4_-_eeg.npy', 'train_-_sub-027_-_audiobook_7_4_-_mel.npy']
# torch.Size([6111, 64]) torch.Size([6111, 10]) ['train_-_sub-027_-_audiobook_7_5_-_eeg.npy', 'train_-_sub-027_-_audiobook_7_5_-_mel.npy']
# torch.Size([6194, 64]) torch.Size([6194, 10]) ['train_-_sub-027_-_audiobook_7_6_-_eeg.npy', 'train_-_sub-027_-_audiobook_7_6_-_mel.npy']
# torch.Size([42767, 64]) torch.Size([42767, 10]) ['train_-_sub-027_-_podcast_10_-_eeg.npy', 'train_-_sub-027_-_podcast_10_-_mel.npy']
# torch.Size([48839, 64]) torch.Size([48839, 10]) ['train_-_sub-027_-_podcast_1_-_eeg.npy', 'train_-_sub-027_-_podcast_1_-_mel.npy']
# torch.Size([58098, 64]) torch.Size([58098, 10]) ['train_-_sub-027_-_podcast_2_-_eeg.npy', 'train_-_sub-027_-_podcast_2_-_mel.npy']
# torch.Size([37233, 64]) torch.Size([37233, 10]) ['train_-_sub-027_-_podcast_3_-_eeg.npy', 'train_-_sub-027_-_podcast_3_-_mel.npy']
# torch.Size([50561, 64]) torch.Size([50561, 10]) ['train_-_sub-027_-_podcast_4_-_eeg.npy', 'train_-_sub-027_-_podcast_4_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-028_-_audiobook_1_-_eeg.npy', 'train_-_sub-028_-_audiobook_1_-_mel.npy']
# torch.Size([12579, 64]) torch.Size([12579, 10]) ['train_-_sub-028_-_audiobook_7_1_-_eeg.npy', 'train_-_sub-028_-_audiobook_7_1_-_mel.npy']
# torch.Size([12381, 64]) torch.Size([12381, 10]) ['train_-_sub-028_-_audiobook_7_2_-_eeg.npy', 'train_-_sub-028_-_audiobook_7_2_-_mel.npy']
# torch.Size([12055, 64]) torch.Size([12055, 10]) ['train_-_sub-028_-_audiobook_7_3_-_eeg.npy', 'train_-_sub-028_-_audiobook_7_3_-_mel.npy']
# torch.Size([16715, 64]) torch.Size([16715, 10]) ['train_-_sub-028_-_audiobook_7_4_-_eeg.npy', 'train_-_sub-028_-_audiobook_7_4_-_mel.npy']
# torch.Size([6111, 64]) torch.Size([6111, 10]) ['train_-_sub-028_-_audiobook_7_5_-_eeg.npy', 'train_-_sub-028_-_audiobook_7_5_-_mel.npy']
# torch.Size([6194, 64]) torch.Size([6194, 10]) ['train_-_sub-028_-_audiobook_7_6_-_eeg.npy', 'train_-_sub-028_-_audiobook_7_6_-_mel.npy']
# torch.Size([42767, 64]) torch.Size([42767, 10]) ['train_-_sub-028_-_podcast_10_-_eeg.npy', 'train_-_sub-028_-_podcast_10_-_mel.npy']
# torch.Size([48839, 64]) torch.Size([48839, 10]) ['train_-_sub-028_-_podcast_1_-_eeg.npy', 'train_-_sub-028_-_podcast_1_-_mel.npy']
# torch.Size([58098, 64]) torch.Size([58098, 10]) ['train_-_sub-028_-_podcast_2_-_eeg.npy', 'train_-_sub-028_-_podcast_2_-_mel.npy']
# torch.Size([37233, 64]) torch.Size([37233, 10]) ['train_-_sub-028_-_podcast_3_-_eeg.npy', 'train_-_sub-028_-_podcast_3_-_mel.npy']
# torch.Size([50561, 64]) torch.Size([50561, 10]) ['train_-_sub-028_-_podcast_4_-_eeg.npy', 'train_-_sub-028_-_podcast_4_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-029_-_audiobook_1_-_eeg.npy', 'train_-_sub-029_-_audiobook_1_-_mel.npy']
# torch.Size([12579, 64]) torch.Size([12579, 10]) ['train_-_sub-029_-_audiobook_7_1_-_eeg.npy', 'train_-_sub-029_-_audiobook_7_1_-_mel.npy']
# torch.Size([12381, 64]) torch.Size([12381, 10]) ['train_-_sub-029_-_audiobook_7_2_-_eeg.npy', 'train_-_sub-029_-_audiobook_7_2_-_mel.npy']
# torch.Size([12055, 64]) torch.Size([12055, 10]) ['train_-_sub-029_-_audiobook_7_3_-_eeg.npy', 'train_-_sub-029_-_audiobook_7_3_-_mel.npy']
# torch.Size([16715, 64]) torch.Size([16715, 10]) ['train_-_sub-029_-_audiobook_7_4_-_eeg.npy', 'train_-_sub-029_-_audiobook_7_4_-_mel.npy']
# torch.Size([6111, 64]) torch.Size([6111, 10]) ['train_-_sub-029_-_audiobook_7_5_-_eeg.npy', 'train_-_sub-029_-_audiobook_7_5_-_mel.npy']
# torch.Size([6194, 64]) torch.Size([6194, 10]) ['train_-_sub-029_-_audiobook_7_6_-_eeg.npy', 'train_-_sub-029_-_audiobook_7_6_-_mel.npy']
# torch.Size([42767, 64]) torch.Size([42767, 10]) ['train_-_sub-029_-_podcast_10_-_eeg.npy', 'train_-_sub-029_-_podcast_10_-_mel.npy']
# torch.Size([48839, 64]) torch.Size([48839, 10]) ['train_-_sub-029_-_podcast_1_-_eeg.npy', 'train_-_sub-029_-_podcast_1_-_mel.npy']
# torch.Size([58098, 64]) torch.Size([58098, 10]) ['train_-_sub-029_-_podcast_2_-_eeg.npy', 'train_-_sub-029_-_podcast_2_-_mel.npy']
# torch.Size([37233, 64]) torch.Size([37233, 10]) ['train_-_sub-029_-_podcast_3_-_eeg.npy', 'train_-_sub-029_-_podcast_3_-_mel.npy']
# torch.Size([50561, 64]) torch.Size([50561, 10]) ['train_-_sub-029_-_podcast_4_-_eeg.npy', 'train_-_sub-029_-_podcast_4_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-030_-_audiobook_1_-_eeg.npy', 'train_-_sub-030_-_audiobook_1_-_mel.npy']
# torch.Size([12579, 64]) torch.Size([12579, 10]) ['train_-_sub-030_-_audiobook_7_1_-_eeg.npy', 'train_-_sub-030_-_audiobook_7_1_-_mel.npy']
# torch.Size([12381, 64]) torch.Size([12381, 10]) ['train_-_sub-030_-_audiobook_7_2_-_eeg.npy', 'train_-_sub-030_-_audiobook_7_2_-_mel.npy']
# torch.Size([12055, 64]) torch.Size([12055, 10]) ['train_-_sub-030_-_audiobook_7_3_-_eeg.npy', 'train_-_sub-030_-_audiobook_7_3_-_mel.npy']
# torch.Size([16715, 64]) torch.Size([16715, 10]) ['train_-_sub-030_-_audiobook_7_4_-_eeg.npy', 'train_-_sub-030_-_audiobook_7_4_-_mel.npy']
# torch.Size([6111, 64]) torch.Size([6111, 10]) ['train_-_sub-030_-_audiobook_7_5_-_eeg.npy', 'train_-_sub-030_-_audiobook_7_5_-_mel.npy']
# torch.Size([6194, 64]) torch.Size([6194, 10]) ['train_-_sub-030_-_audiobook_7_6_-_eeg.npy', 'train_-_sub-030_-_audiobook_7_6_-_mel.npy']
# torch.Size([42767, 64]) torch.Size([42767, 10]) ['train_-_sub-030_-_podcast_10_-_eeg.npy', 'train_-_sub-030_-_podcast_10_-_mel.npy']
# torch.Size([48839, 64]) torch.Size([48839, 10]) ['train_-_sub-030_-_podcast_1_-_eeg.npy', 'train_-_sub-030_-_podcast_1_-_mel.npy']
# torch.Size([58098, 64]) torch.Size([58098, 10]) ['train_-_sub-030_-_podcast_2_-_eeg.npy', 'train_-_sub-030_-_podcast_2_-_mel.npy']
# torch.Size([37233, 64]) torch.Size([37233, 10]) ['train_-_sub-030_-_podcast_3_-_eeg.npy', 'train_-_sub-030_-_podcast_3_-_mel.npy']
# torch.Size([50561, 64]) torch.Size([50561, 10]) ['train_-_sub-030_-_podcast_4_-_eeg.npy', 'train_-_sub-030_-_podcast_4_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-031_-_audiobook_1_-_eeg.npy', 'train_-_sub-031_-_audiobook_1_-_mel.npy']
# torch.Size([12579, 64]) torch.Size([12579, 10]) ['train_-_sub-031_-_audiobook_7_1_-_eeg.npy', 'train_-_sub-031_-_audiobook_7_1_-_mel.npy']
# torch.Size([12381, 64]) torch.Size([12381, 10]) ['train_-_sub-031_-_audiobook_7_2_-_eeg.npy', 'train_-_sub-031_-_audiobook_7_2_-_mel.npy']
# torch.Size([12055, 64]) torch.Size([12055, 10]) ['train_-_sub-031_-_audiobook_7_3_-_eeg.npy', 'train_-_sub-031_-_audiobook_7_3_-_mel.npy']
# torch.Size([16715, 64]) torch.Size([16715, 10]) ['train_-_sub-031_-_audiobook_7_4_-_eeg.npy', 'train_-_sub-031_-_audiobook_7_4_-_mel.npy']
# torch.Size([6111, 64]) torch.Size([6111, 10]) ['train_-_sub-031_-_audiobook_7_5_-_eeg.npy', 'train_-_sub-031_-_audiobook_7_5_-_mel.npy']
# torch.Size([6194, 64]) torch.Size([6194, 10]) ['train_-_sub-031_-_audiobook_7_6_-_eeg.npy', 'train_-_sub-031_-_audiobook_7_6_-_mel.npy']
# torch.Size([42767, 64]) torch.Size([42767, 10]) ['train_-_sub-031_-_podcast_10_-_eeg.npy', 'train_-_sub-031_-_podcast_10_-_mel.npy']
# torch.Size([48839, 64]) torch.Size([48839, 10]) ['train_-_sub-031_-_podcast_1_-_eeg.npy', 'train_-_sub-031_-_podcast_1_-_mel.npy']
# torch.Size([58098, 64]) torch.Size([58098, 10]) ['train_-_sub-031_-_podcast_2_-_eeg.npy', 'train_-_sub-031_-_podcast_2_-_mel.npy']
# torch.Size([37233, 64]) torch.Size([37233, 10]) ['train_-_sub-031_-_podcast_3_-_eeg.npy', 'train_-_sub-031_-_podcast_3_-_mel.npy']
# torch.Size([50561, 64]) torch.Size([50561, 10]) ['train_-_sub-031_-_podcast_4_-_eeg.npy', 'train_-_sub-031_-_podcast_4_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-032_-_audiobook_1_-_eeg.npy', 'train_-_sub-032_-_audiobook_1_-_mel.npy']
# torch.Size([38252, 64]) torch.Size([38252, 10]) ['train_-_sub-032_-_audiobook_8_1_-_eeg.npy', 'train_-_sub-032_-_audiobook_8_1_-_mel.npy']
# torch.Size([39891, 64]) torch.Size([39891, 10]) ['train_-_sub-032_-_audiobook_8_2_-_eeg.npy', 'train_-_sub-032_-_audiobook_8_2_-_mel.npy']
# torch.Size([42767, 64]) torch.Size([42767, 10]) ['train_-_sub-032_-_podcast_10_-_eeg.npy', 'train_-_sub-032_-_podcast_10_-_mel.npy']
# torch.Size([50958, 64]) torch.Size([50958, 10]) ['train_-_sub-032_-_podcast_5_-_eeg.npy', 'train_-_sub-032_-_podcast_5_-_mel.npy']
# torch.Size([43248, 64]) torch.Size([43248, 10]) ['train_-_sub-032_-_podcast_6_-_eeg.npy', 'train_-_sub-032_-_podcast_6_-_mel.npy']
# torch.Size([50432, 64]) torch.Size([50432, 10]) ['train_-_sub-032_-_podcast_7_-_eeg.npy', 'train_-_sub-032_-_podcast_7_-_mel.npy']
# torch.Size([51868, 64]) torch.Size([51868, 10]) ['train_-_sub-032_-_podcast_8_-_eeg.npy', 'train_-_sub-032_-_podcast_8_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-033_-_audiobook_1_-_eeg.npy', 'train_-_sub-033_-_audiobook_1_-_mel.npy']
# torch.Size([38252, 64]) torch.Size([38252, 10]) ['train_-_sub-033_-_audiobook_8_1_-_eeg.npy', 'train_-_sub-033_-_audiobook_8_1_-_mel.npy']
# torch.Size([39891, 64]) torch.Size([39891, 10]) ['train_-_sub-033_-_audiobook_8_2_-_eeg.npy', 'train_-_sub-033_-_audiobook_8_2_-_mel.npy']
# torch.Size([42767, 64]) torch.Size([42767, 10]) ['train_-_sub-033_-_podcast_10_-_eeg.npy', 'train_-_sub-033_-_podcast_10_-_mel.npy']
# torch.Size([50958, 64]) torch.Size([50958, 10]) ['train_-_sub-033_-_podcast_5_-_eeg.npy', 'train_-_sub-033_-_podcast_5_-_mel.npy']
# torch.Size([43248, 64]) torch.Size([43248, 10]) ['train_-_sub-033_-_podcast_6_-_eeg.npy', 'train_-_sub-033_-_podcast_6_-_mel.npy']
# torch.Size([50432, 64]) torch.Size([50432, 10]) ['train_-_sub-033_-_podcast_7_-_eeg.npy', 'train_-_sub-033_-_podcast_7_-_mel.npy']
# torch.Size([51868, 64]) torch.Size([51868, 10]) ['train_-_sub-033_-_podcast_8_-_eeg.npy', 'train_-_sub-033_-_podcast_8_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-034_-_audiobook_1_-_eeg.npy', 'train_-_sub-034_-_audiobook_1_-_mel.npy']
# torch.Size([38252, 64]) torch.Size([38252, 10]) ['train_-_sub-034_-_audiobook_8_1_-_eeg.npy', 'train_-_sub-034_-_audiobook_8_1_-_mel.npy']
# torch.Size([39891, 64]) torch.Size([39891, 10]) ['train_-_sub-034_-_audiobook_8_2_-_eeg.npy', 'train_-_sub-034_-_audiobook_8_2_-_mel.npy']
# torch.Size([42767, 64]) torch.Size([42767, 10]) ['train_-_sub-034_-_podcast_10_-_eeg.npy', 'train_-_sub-034_-_podcast_10_-_mel.npy']
# torch.Size([50958, 64]) torch.Size([50958, 10]) ['train_-_sub-034_-_podcast_5_-_eeg.npy', 'train_-_sub-034_-_podcast_5_-_mel.npy']
# torch.Size([43248, 64]) torch.Size([43248, 10]) ['train_-_sub-034_-_podcast_6_-_eeg.npy', 'train_-_sub-034_-_podcast_6_-_mel.npy']
# torch.Size([50432, 64]) torch.Size([50432, 10]) ['train_-_sub-034_-_podcast_7_-_eeg.npy', 'train_-_sub-034_-_podcast_7_-_mel.npy']
# torch.Size([51868, 64]) torch.Size([51868, 10]) ['train_-_sub-034_-_podcast_8_-_eeg.npy', 'train_-_sub-034_-_podcast_8_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-035_-_audiobook_1_-_eeg.npy', 'train_-_sub-035_-_audiobook_1_-_mel.npy']
# torch.Size([38252, 64]) torch.Size([38252, 10]) ['train_-_sub-035_-_audiobook_8_1_-_eeg.npy', 'train_-_sub-035_-_audiobook_8_1_-_mel.npy']
# torch.Size([39891, 64]) torch.Size([39891, 10]) ['train_-_sub-035_-_audiobook_8_2_-_eeg.npy', 'train_-_sub-035_-_audiobook_8_2_-_mel.npy']
# torch.Size([42767, 64]) torch.Size([42767, 10]) ['train_-_sub-035_-_podcast_10_-_eeg.npy', 'train_-_sub-035_-_podcast_10_-_mel.npy']
# torch.Size([50958, 64]) torch.Size([50958, 10]) ['train_-_sub-035_-_podcast_5_-_eeg.npy', 'train_-_sub-035_-_podcast_5_-_mel.npy']
# torch.Size([43248, 64]) torch.Size([43248, 10]) ['train_-_sub-035_-_podcast_6_-_eeg.npy', 'train_-_sub-035_-_podcast_6_-_mel.npy']
# torch.Size([50432, 64]) torch.Size([50432, 10]) ['train_-_sub-035_-_podcast_7_-_eeg.npy', 'train_-_sub-035_-_podcast_7_-_mel.npy']
# torch.Size([51868, 64]) torch.Size([51868, 10]) ['train_-_sub-035_-_podcast_8_-_eeg.npy', 'train_-_sub-035_-_podcast_8_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-036_-_audiobook_1_-_eeg.npy', 'train_-_sub-036_-_audiobook_1_-_mel.npy']
# torch.Size([38252, 64]) torch.Size([38252, 10]) ['train_-_sub-036_-_audiobook_8_1_-_eeg.npy', 'train_-_sub-036_-_audiobook_8_1_-_mel.npy']
# torch.Size([39891, 64]) torch.Size([39891, 10]) ['train_-_sub-036_-_audiobook_8_2_-_eeg.npy', 'train_-_sub-036_-_audiobook_8_2_-_mel.npy']
# torch.Size([42767, 64]) torch.Size([42767, 10]) ['train_-_sub-036_-_podcast_10_-_eeg.npy', 'train_-_sub-036_-_podcast_10_-_mel.npy']
# torch.Size([50958, 64]) torch.Size([50958, 10]) ['train_-_sub-036_-_podcast_5_-_eeg.npy', 'train_-_sub-036_-_podcast_5_-_mel.npy']
# torch.Size([43248, 64]) torch.Size([43248, 10]) ['train_-_sub-036_-_podcast_6_-_eeg.npy', 'train_-_sub-036_-_podcast_6_-_mel.npy']
# torch.Size([50432, 64]) torch.Size([50432, 10]) ['train_-_sub-036_-_podcast_7_-_eeg.npy', 'train_-_sub-036_-_podcast_7_-_mel.npy']
# torch.Size([51868, 64]) torch.Size([51868, 10]) ['train_-_sub-036_-_podcast_8_-_eeg.npy', 'train_-_sub-036_-_podcast_8_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-037_-_audiobook_1_-_eeg.npy', 'train_-_sub-037_-_audiobook_1_-_mel.npy']
# ...
# torch.Size([41358, 64]) torch.Size([41358, 10]) ['train_-_sub-066_-_podcast_28_-_eeg.npy', 'train_-_sub-066_-_podcast_28_-_mel.npy']
# torch.Size([46148, 64]) torch.Size([46148, 10]) ['train_-_sub-066_-_podcast_29_-_eeg.npy', 'train_-_sub-066_-_podcast_29_-_mel.npy']
# torch.Size([49818, 64]) torch.Size([49818, 10]) ['train_-_sub-066_-_podcast_30_-_eeg.npy', 'train_-_sub-066_-_podcast_30_-_mel.npy']
# torch.Size([45430, 64]) torch.Size([45430, 10]) ['train_-_sub-066_-_podcast_31_-_eeg.npy', 'train_-_sub-066_-_podcast_31_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-067_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-067_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-067_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-067_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-067_-_audiobook_1_-_eeg.npy', 'train_-_sub-067_-_audiobook_1_-_mel.npy']
# torch.Size([41358, 64]) torch.Size([41358, 10]) ['train_-_sub-067_-_podcast_28_-_eeg.npy', 'train_-_sub-067_-_podcast_28_-_mel.npy']
# torch.Size([46148, 64]) torch.Size([46148, 10]) ['train_-_sub-067_-_podcast_29_-_eeg.npy', 'train_-_sub-067_-_podcast_29_-_mel.npy']
# torch.Size([49818, 64]) torch.Size([49818, 10]) ['train_-_sub-067_-_podcast_30_-_eeg.npy', 'train_-_sub-067_-_podcast_30_-_mel.npy']
# torch.Size([45430, 64]) torch.Size([45430, 10]) ['train_-_sub-067_-_podcast_31_-_eeg.npy', 'train_-_sub-067_-_podcast_31_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-068_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-068_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-068_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-068_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-068_-_audiobook_1_-_eeg.npy', 'train_-_sub-068_-_audiobook_1_-_mel.npy']
# torch.Size([41358, 64]) torch.Size([41358, 10]) ['train_-_sub-068_-_podcast_28_-_eeg.npy', 'train_-_sub-068_-_podcast_28_-_mel.npy']
# torch.Size([46148, 64]) torch.Size([46148, 10]) ['train_-_sub-068_-_podcast_29_-_eeg.npy', 'train_-_sub-068_-_podcast_29_-_mel.npy']
# torch.Size([49818, 64]) torch.Size([49818, 10]) ['train_-_sub-068_-_podcast_30_-_eeg.npy', 'train_-_sub-068_-_podcast_30_-_mel.npy']
# torch.Size([45430, 64]) torch.Size([45430, 10]) ['train_-_sub-068_-_podcast_31_-_eeg.npy', 'train_-_sub-068_-_podcast_31_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-069_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-069_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-069_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-069_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-069_-_audiobook_1_-_eeg.npy', 'train_-_sub-069_-_audiobook_1_-_mel.npy']
# torch.Size([41358, 64]) torch.Size([41358, 10]) ['train_-_sub-069_-_podcast_28_-_eeg.npy', 'train_-_sub-069_-_podcast_28_-_mel.npy']
# torch.Size([46148, 64]) torch.Size([46148, 10]) ['train_-_sub-069_-_podcast_29_-_eeg.npy', 'train_-_sub-069_-_podcast_29_-_mel.npy']
# torch.Size([49818, 64]) torch.Size([49818, 10]) ['train_-_sub-069_-_podcast_30_-_eeg.npy', 'train_-_sub-069_-_podcast_30_-_mel.npy']
# torch.Size([45430, 64]) torch.Size([45430, 10]) ['train_-_sub-069_-_podcast_31_-_eeg.npy', 'train_-_sub-069_-_podcast_31_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-070_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-070_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-070_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-070_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-070_-_audiobook_1_-_eeg.npy', 'train_-_sub-070_-_audiobook_1_-_mel.npy']
# torch.Size([41358, 64]) torch.Size([41358, 10]) ['train_-_sub-070_-_podcast_28_-_eeg.npy', 'train_-_sub-070_-_podcast_28_-_mel.npy']
# torch.Size([46148, 64]) torch.Size([46148, 10]) ['train_-_sub-070_-_podcast_29_-_eeg.npy', 'train_-_sub-070_-_podcast_29_-_mel.npy']
# torch.Size([49818, 64]) torch.Size([49818, 10]) ['train_-_sub-070_-_podcast_30_-_eeg.npy', 'train_-_sub-070_-_podcast_30_-_mel.npy']
# torch.Size([45430, 64]) torch.Size([45430, 10]) ['train_-_sub-070_-_podcast_31_-_eeg.npy', 'train_-_sub-070_-_podcast_31_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-071_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-071_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-071_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-071_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-071_-_audiobook_1_-_eeg.npy', 'train_-_sub-071_-_audiobook_1_-_mel.npy']
# torch.Size([41358, 64]) torch.Size([41358, 10]) ['train_-_sub-071_-_podcast_28_-_eeg.npy', 'train_-_sub-071_-_podcast_28_-_mel.npy']
# torch.Size([46148, 64]) torch.Size([46148, 10]) ['train_-_sub-071_-_podcast_29_-_eeg.npy', 'train_-_sub-071_-_podcast_29_-_mel.npy']
# torch.Size([49818, 64]) torch.Size([49818, 10]) ['train_-_sub-071_-_podcast_30_-_eeg.npy', 'train_-_sub-071_-_podcast_30_-_mel.npy']
# torch.Size([45430, 64]) torch.Size([45430, 10]) ['train_-_sub-071_-_podcast_31_-_eeg.npy', 'train_-_sub-071_-_podcast_31_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-072_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-072_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-072_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-072_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-072_-_audiobook_1_-_eeg.npy', 'train_-_sub-072_-_audiobook_1_-_mel.npy']
# torch.Size([48314, 64]) torch.Size([48314, 10]) ['train_-_sub-072_-_podcast_32_-_eeg.npy', 'train_-_sub-072_-_podcast_32_-_mel.npy']
# torch.Size([36377, 64]) torch.Size([36377, 10]) ['train_-_sub-072_-_podcast_33_-_eeg.npy', 'train_-_sub-072_-_podcast_33_-_mel.npy']
# torch.Size([49294, 64]) torch.Size([49294, 10]) ['train_-_sub-072_-_podcast_34_-_eeg.npy', 'train_-_sub-072_-_podcast_34_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-073_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-073_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-073_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-073_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-073_-_audiobook_1_-_eeg.npy', 'train_-_sub-073_-_audiobook_1_-_mel.npy']
# torch.Size([48314, 64]) torch.Size([48314, 10]) ['train_-_sub-073_-_podcast_32_-_eeg.npy', 'train_-_sub-073_-_podcast_32_-_mel.npy']
# torch.Size([36377, 64]) torch.Size([36377, 10]) ['train_-_sub-073_-_podcast_33_-_eeg.npy', 'train_-_sub-073_-_podcast_33_-_mel.npy']
# torch.Size([49294, 64]) torch.Size([49294, 10]) ['train_-_sub-073_-_podcast_34_-_eeg.npy', 'train_-_sub-073_-_podcast_34_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-074_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-074_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-074_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-074_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-074_-_audiobook_1_-_eeg.npy', 'train_-_sub-074_-_audiobook_1_-_mel.npy']
# torch.Size([48314, 64]) torch.Size([48314, 10]) ['train_-_sub-074_-_podcast_32_-_eeg.npy', 'train_-_sub-074_-_podcast_32_-_mel.npy']
# torch.Size([36377, 64]) torch.Size([36377, 10]) ['train_-_sub-074_-_podcast_33_-_eeg.npy', 'train_-_sub-074_-_podcast_33_-_mel.npy']
# torch.Size([49294, 64]) torch.Size([49294, 10]) ['train_-_sub-074_-_podcast_34_-_eeg.npy', 'train_-_sub-074_-_podcast_34_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-075_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-075_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-075_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-075_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-075_-_audiobook_1_-_eeg.npy', 'train_-_sub-075_-_audiobook_1_-_mel.npy']
# torch.Size([48314, 64]) torch.Size([48314, 10]) ['train_-_sub-075_-_podcast_32_-_eeg.npy', 'train_-_sub-075_-_podcast_32_-_mel.npy']
# torch.Size([36377, 64]) torch.Size([36377, 10]) ['train_-_sub-075_-_podcast_33_-_eeg.npy', 'train_-_sub-075_-_podcast_33_-_mel.npy']
# torch.Size([49294, 64]) torch.Size([49294, 10]) ['train_-_sub-075_-_podcast_34_-_eeg.npy', 'train_-_sub-075_-_podcast_34_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-076_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-076_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-076_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-076_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-076_-_audiobook_1_-_eeg.npy', 'train_-_sub-076_-_audiobook_1_-_mel.npy']
# torch.Size([48314, 64]) torch.Size([48314, 10]) ['train_-_sub-076_-_podcast_32_-_eeg.npy', 'train_-_sub-076_-_podcast_32_-_mel.npy']
# torch.Size([36377, 64]) torch.Size([36377, 10]) ['train_-_sub-076_-_podcast_33_-_eeg.npy', 'train_-_sub-076_-_podcast_33_-_mel.npy']
# torch.Size([49294, 64]) torch.Size([49294, 10]) ['train_-_sub-076_-_podcast_34_-_eeg.npy', 'train_-_sub-076_-_podcast_34_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-077_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-077_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-077_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-077_-_audiobook_14_2_-_mel.npy']
# torch.Size([49294, 64]) torch.Size([49294, 10]) ['train_-_sub-077_-_podcast_34_-_eeg.npy', 'train_-_sub-077_-_podcast_34_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-078_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-078_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-078_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-078_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-078_-_audiobook_1_-_eeg.npy', 'train_-_sub-078_-_audiobook_1_-_mel.npy']
# torch.Size([48314, 64]) torch.Size([48314, 10]) ['train_-_sub-078_-_podcast_32_-_eeg.npy', 'train_-_sub-078_-_podcast_32_-_mel.npy']
# torch.Size([36377, 64]) torch.Size([36377, 10]) ['train_-_sub-078_-_podcast_33_-_eeg.npy', 'train_-_sub-078_-_podcast_33_-_mel.npy']
# torch.Size([49294, 64]) torch.Size([49294, 10]) ['train_-_sub-078_-_podcast_34_-_eeg.npy', 'train_-_sub-078_-_podcast_34_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-079_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-079_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-079_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-079_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-079_-_audiobook_1_-_eeg.npy', 'train_-_sub-079_-_audiobook_1_-_mel.npy']
# torch.Size([47930, 64]) torch.Size([47930, 10]) ['train_-_sub-079_-_podcast_35_-_eeg.npy', 'train_-_sub-079_-_podcast_35_-_mel.npy']
# torch.Size([47287, 64]) torch.Size([47287, 10]) ['train_-_sub-079_-_podcast_36_-_eeg.npy', 'train_-_sub-079_-_podcast_36_-_mel.npy']
# torch.Size([43750, 64]) torch.Size([43750, 10]) ['train_-_sub-079_-_podcast_37_-_eeg.npy', 'train_-_sub-079_-_podcast_37_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-080_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-080_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-080_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-080_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-080_-_audiobook_1_-_eeg.npy', 'train_-_sub-080_-_audiobook_1_-_mel.npy']
# torch.Size([47930, 64]) torch.Size([47930, 10]) ['train_-_sub-080_-_podcast_35_-_eeg.npy', 'train_-_sub-080_-_podcast_35_-_mel.npy']
# torch.Size([47287, 64]) torch.Size([47287, 10]) ['train_-_sub-080_-_podcast_36_-_eeg.npy', 'train_-_sub-080_-_podcast_36_-_mel.npy']
# torch.Size([43750, 64]) torch.Size([43750, 10]) ['train_-_sub-080_-_podcast_37_-_eeg.npy', 'train_-_sub-080_-_podcast_37_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-081_-_audiobook_1_-_eeg.npy', 'train_-_sub-081_-_audiobook_1_-_mel.npy']
# torch.Size([47287, 64]) torch.Size([47287, 10]) ['train_-_sub-081_-_podcast_36_-_eeg.npy', 'train_-_sub-081_-_podcast_36_-_mel.npy']
# torch.Size([43750, 64]) torch.Size([43750, 10]) ['train_-_sub-081_-_podcast_37_-_eeg.npy', 'train_-_sub-081_-_podcast_37_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-082_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-082_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-082_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-082_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-082_-_audiobook_1_-_eeg.npy', 'train_-_sub-082_-_audiobook_1_-_mel.npy']
# torch.Size([47930, 64]) torch.Size([47930, 10]) ['train_-_sub-082_-_podcast_35_-_eeg.npy', 'train_-_sub-082_-_podcast_35_-_mel.npy']
# torch.Size([47287, 64]) torch.Size([47287, 10]) ['train_-_sub-082_-_podcast_36_-_eeg.npy', 'train_-_sub-082_-_podcast_36_-_mel.npy']
# torch.Size([43750, 64]) torch.Size([43750, 10]) ['train_-_sub-082_-_podcast_37_-_eeg.npy', 'train_-_sub-082_-_podcast_37_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-083_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-083_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-083_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-083_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-083_-_audiobook_1_-_eeg.npy', 'train_-_sub-083_-_audiobook_1_-_mel.npy']
# torch.Size([47930, 64]) torch.Size([47930, 10]) ['train_-_sub-083_-_podcast_35_-_eeg.npy', 'train_-_sub-083_-_podcast_35_-_mel.npy']
# torch.Size([47287, 64]) torch.Size([47287, 10]) ['train_-_sub-083_-_podcast_36_-_eeg.npy', 'train_-_sub-083_-_podcast_36_-_mel.npy']
# torch.Size([43750, 64]) torch.Size([43750, 10]) ['train_-_sub-083_-_podcast_37_-_eeg.npy', 'train_-_sub-083_-_podcast_37_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-084_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-084_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-084_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-084_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-084_-_audiobook_1_-_eeg.npy', 'train_-_sub-084_-_audiobook_1_-_mel.npy']
# torch.Size([47930, 64]) torch.Size([47930, 10]) ['train_-_sub-084_-_podcast_35_-_eeg.npy', 'train_-_sub-084_-_podcast_35_-_mel.npy']
# torch.Size([47287, 64]) torch.Size([47287, 10]) ['train_-_sub-084_-_podcast_36_-_eeg.npy', 'train_-_sub-084_-_podcast_36_-_mel.npy']
# torch.Size([43750, 64]) torch.Size([43750, 10]) ['train_-_sub-084_-_podcast_37_-_eeg.npy', 'train_-_sub-084_-_podcast_37_-_mel.npy']
# torch.Size([53872, 64]) torch.Size([53872, 10]) ['train_-_sub-085_-_audiobook_14_1_-_eeg.npy', 'train_-_sub-085_-_audiobook_14_1_-_mel.npy']
# torch.Size([58788, 64]) torch.Size([58788, 10]) ['train_-_sub-085_-_audiobook_14_2_-_eeg.npy', 'train_-_sub-085_-_audiobook_14_2_-_mel.npy']
# torch.Size([47964, 64]) torch.Size([47964, 10]) ['train_-_sub-085_-_audiobook_1_-_eeg.npy', 'train_-_sub-085_-_audiobook_1_-_mel.npy']
# torch.Size([47930, 64]) torch.Size([47930, 10]) ['train_-_sub-085_-_podcast_35_-_eeg.npy', 'train_-_sub-085_-_podcast_35_-_mel.npy']
# torch.Size([47287, 64]) torch.Size([47287, 10]) ['train_-_sub-085_-_podcast_36_-_eeg.npy', 'train_-_sub-085_-_podcast_36_-_mel.npy']
# torch.Size([43750, 64]) torch.Size([43750, 10]) ['train_-_sub-085_-_podcast_37_-_eeg.npy', 'train_-_sub-085_-_podcast_37_-_mel.npy']
